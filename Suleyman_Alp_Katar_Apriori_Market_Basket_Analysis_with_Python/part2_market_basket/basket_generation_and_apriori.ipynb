# %%
# Step 1: Load and Preprocess Product Data 
#We prepare the product list and assign weights based on prices (assuming cheaper items are more common).

import pandas as pd
import numpy as np

# Load and clean column headers
df = pd.read_excel("Market_Price_Comparison_2025.xlsx")
df.columns = df.columns.str.strip()  # Remove leading/trailing whitespace

# Now extract the product and price columns
products = df[['Supermarket A Product', 'Supermarket A Price']].copy()
products.columns = ['Product', 'Price']

# Drop duplicates and NaNs
products.dropna(subset=['Product', 'Price'], inplace=True)
products = products.drop_duplicates().reset_index(drop=True)

# Show cleaned data
products.head()
# Out:
#                                      Product   Price
# 0                   Reis Yeşil Mercimek 1 Kg  129.95
# 1  Hasata Yozgat Sultani Yeşil Mercimek 1 Kg  135.95
# 2                 Reis Kırmızı Mercimek 1 Kg  140.95
# 3                    Reis Sarı Mercimek 1 Kg  222.95
# 4          Reis Royal Beluga Mercimeği 500 G  182.95

# %%
# Step 2: Calculate Item Popularity Based on Price (cheaper = more frequent)
# We invert prices to approximate item popularity (cheaper items = higher probability).

# Avoid division by zero and normalize
products['Inverse_Price'] = 1 / (products['Price'] + 1e-6)

# Normalize to get probabilities that sum to 1
products['Probability'] = products['Inverse_Price'] / products['Inverse_Price'].sum()

# Preview the resulting probabilities
products[['Product', 'Price', 'Probability']].head(10)
# Out:
#                                      Product   Price  Probability
# 0                   Reis Yeşil Mercimek 1 Kg  129.95     0.000336
# 1  Hasata Yozgat Sultani Yeşil Mercimek 1 Kg  135.95     0.000321
# 2                 Reis Kırmızı Mercimek 1 Kg  140.95     0.000310
# 3                    Reis Sarı Mercimek 1 Kg  222.95     0.000196
# 4          Reis Royal Beluga Mercimeği 500 G  182.95     0.000238
# 5        Hasata Mardin Kırmızı Mercimek 1 Kg   69.95     0.000624
# 6              Superfresh Taze Fasulye 450 G   99.95     0.000437
# 7                   Superfresh Bezelye 450 G   79.95     0.000546
# 8                   Superfresh Ispanak 450 G   76.95     0.000567
# 9         Superfresh Elma Dilim Patates 1 Kg  199.95     0.000218

# %%
# Step 3: Simulate 10,000 Customers
#Each customer gets a random basket size (1 to 25), with items sampled using weighted probabilities.

import random

# Set seed for reproducibility
random.seed(42)
np.random.seed(42)

# Number of customers
num_customers = 10000

# Create list of products and their associated probabilities
product_list = products['Product'].tolist()
probabilities = products['Probability'].tolist()

# Simulate transactions
transactions = []

for _ in range(num_customers):
    basket_size = np.random.randint(1, 26)  # Basket size between 1 and 25
    basket = np.random.choice(product_list, size=basket_size, replace=False, p=probabilities)
    transactions.append(basket.tolist())

# Preview first 5 transactions
transactions[:5]
# Out:
# [['Exotic Portakal Havuç Suyu 750 Cc',
#   'Ot Dergisi',
#   'Tamek Karışık Meyve Nektarı 1 Lt',
#   'Ülker Laviva Selection Antep Fıstıklı Gofret 45 G',
#   'Bağdat İsot Biber 80 G',
#   'Mr.Muscle Süper Güç Çok Amaçlı Temizleyici 750 Ml',
#   'Knorr Fırında Tavuk Çeşnisi Kekikli Fesleğenli Susamlı 29 G'],
#  ['Yupo Jelly Portakal Halkası 70 G',
#   'Eti Gold Çikolatalı Gofret 29 g',
#   'Superfresh Milföy Hamuru 1 Kg',
#   'Namet 7/24 Dana Macar Salam 60 G',
#   'Tat Bezelye 830 G',
#   'Dreamies Somonlu Kedi Ödül Maması 60 G',
#   'Cumhuriyet Gazetesi',
#   'Ot Dergisi',
#   'Pastavilla Tel Şehriye 500 G',
#   'Eti Burçak Kakao Kremalı Bisküvi 100 g',
#   'Bağdat Kimyon Tuzluklu Cam 48 G',
#   'Filiz Tel Şehriye 500 G',
#   'Ülker Çikolatalı Gofret Maxi 47 G',
#   'Garnier Çarpıcı Renkler 1.0 Ekstra Yoğun Siyah',
#   'Pakmaya Mayalı Poğaça Harcı 35 G',
#   'Fersan Üzüm Sirke 2 L',
#   'Tamek Kayısı Nektarı 200 Ml',
#   'Birgün Gazetesi',
#   'Ülker Susamlı Çubuk Kraker 70 G',
#   'Nestle Damak Ala Beyaz Gofret 30 G',
#   'Hacı Şakir Bahar Çiçekleri Lavanta Güzellik Sabunu 4X70 G'],
#  ['First Sensations Tropikal Meyve Aromalı Sakız 27 G',
#   'Arifoğlu Sarımsak Granül 40 G',
#   'Duru Şehriyeli Pilavlık Bulgur 1 Kg',
#   'Magnum Cookie 95 Ml',
#   'Ülker Saklıköy Çikolata Kremalı Bisküvi 87 G',
#   'Bağdat Galeta Unu 250 G',
#   'Feast Vişne 400 G',
#   "Doğadan Form Çay Kiraz Saplı 20'li",
#   'Sana Paket Margarin Tereyağı Lezzeti 250 G',
#   'Haribo Starmix 80 G',
#   'Ülker Çikolatalı Gofret Maxi 47 G',
#   'Heinz Meksika Fasülyesi 400 G',
#   'Leman',
#   'Kekstra Konfeti Muffin Kek Kakaolu 38 G',
#   'Cumhuriyet Gazetesi',
#   'Uludağ Frutti Extra Orman Meyveli Pet 1 L',
#   'Alpella Kakaolu Kaplamalı Kremalı Mini Rulo Pasta 28 G',
#   'Whiskas Somonlu Poşet Yaş Mama 85 G',
#   'Ülker Krispi Baharatlı Çubuk Kraker 43 G'],
#  ['Lipton Ice Tea Şeftali Pet 1 L',
#   'Algida Maraş Usulü Sade Dondurma Cup 105 ml',
#   'Alpimilk Çikolatalı Süt 180 Ml',
#   'Eti Karamelli Patlaklı Sütlü Çikolata 15 G',
#   'Kinder Süt Dilimi 28 gr',
#   "Orkid Ultra Extra Hijyenik Ped Normal Tekli Paket 8'li",
#   'Türkiye Gazetesi',
#   'Hacı Şakir Bahar Çiçekleri Lavanta Güzellik Sabunu 4X70 G',
#   'Arbella Burgu Makarna 500 G',
#   'Eti Lifalif Puffed Granola Kakao 160G',
#   'Pastavilla İri Arpa Şehriye 500 G',
#   'Tat Ketçap Tatlı 390 G',
#   'Hero Goodies Fındık Kakao Meyve Bar 30 G',
#   'Filiz Kuskus Makarna 500 G',
#   'Halley Çikolata Kaplamalı Bisküvi 30 G',
#   "Kotex Aplikatörlü Tampon Süper 8'li",
#   'Master Nut X NR1 Karışık Kuruyemiş 140 G',
#   'Mr. Muscle Advanced Power Mutfak Temizleyici Limon 750ml'],
#  ['Eti Popkek Mini Hindistan Cevizli Kek 180 G',
#   'Albeni Çikolata Kaplamalı Kek 43 G',
#   'Filiz Kalem Makarna 500 G',
#   'Hasata Pilavlık Antep Bulguru 1 Kg',
#   'Yeni Şafak Gazetesi',
#   'Eti Canga Yerfıstığı Kaplı Fındık Kremalı Gofret 34 G',
#   'Lipton Ice Tea Şeftali Şekersiz Kutu 330 ml']]

# %%
# Step 4: Store Transactions
#Format each customer’s basket into a dataset where each row is a transaction.

# Convert transactions to DataFrame
transaction_df = pd.DataFrame({
    'TransactionID': range(1, len(transactions) + 1),
    'Basket': [', '.join(basket) for basket in transactions]
})

# Preview the transaction dataset
transaction_df.head()
# Out:
#    TransactionID                                             Basket
# 0              1  Exotic Portakal Havuç Suyu 750 Cc, Ot Dergisi,...
# 1              2  Yupo Jelly Portakal Halkası 70 G, Eti Gold Çik...
# 2              3  First Sensations Tropikal Meyve Aromalı Sakız ...
# 3              4  Lipton Ice Tea Şeftali Pet 1 L, Algida Maraş U...
# 4              5  Eti Popkek Mini Hindistan Cevizli Kek 180 G, A...

# %%
#Step 5: Reuse or Load Synthetic Transactions
# Use the previously created transaction_df or load the saved transaction dataset.

#Step 6: Convert Data to Transaction Format
# We’ll convert each basket into a one-hot encoded format suitable for mlxtend's Apriori algorithm.


import pandas as pd
import numpy as np
import random

df = pd.read_excel("Market_Price_Comparison_2025.xlsx")
df.columns = df.columns.str.strip()

products = df[['Supermarket A Product', 'Supermarket A Price']].copy()
products.columns = ['Product', 'Price']
products.dropna(subset=['Product', 'Price'], inplace=True)
products = products.drop_duplicates().reset_index(drop=True)

# Calculate probabilities
products['Inverse_Price'] = 1 / (products['Price'] + 1e-6)
products['Probability'] = products['Inverse_Price'] / products['Inverse_Price'].sum()

# Simulate transactions
random.seed(42)
np.random.seed(42)
num_customers = 10000
product_list = products['Product'].tolist()
probabilities = products['Probability'].tolist()

transactions = []
for _ in range(num_customers):
    basket_size = np.random.randint(1, 26)
    basket = np.random.choice(product_list, size=basket_size, replace=False, p=probabilities)
    transactions.append(basket.tolist())

# %%
#Step 7: Run Apriori Algorithm Extract frequent itemsets using a support threshold

# Step 3: Run Apriori Algorithm
from mlxtend.frequent_patterns import apriori

# Convert to one-hot encoding
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_array = te.fit_transform(transactions)
df_encoded = pd.DataFrame(te_array, columns=te.columns_)

# Apply Apriori with min support of 1%
frequent_itemsets = apriori(df_encoded, min_support=0.01, use_colnames=True)

# Sort by support descending
frequent_itemsets = frequent_itemsets.sort_values(by='support', ascending=False)

# Show top frequent itemsets
frequent_itemsets.head(10)
# Out:
#      support                                           itemsets
# 359   0.0766                     (Ülker Badem Kraker Sade 38 G)
# 369   0.0722          (Ülker Dankek Pöti Havuçlu Tarçınlı 35 G)
# 158   0.0703                        (Indomie Tavuk Noodle 70 G)
# 157   0.0683                      (Indomie Sebzeli Noodle 75 G)
# 380   0.0658          (Ülker Krispi Peynirli Çubuk Kraker 43 G)
# 10    0.0648  (Alpella Kakaolu Kaplamalı Kremalı Mini Rulo P...
# 99    0.0647                  (Eti Gold Çikolatalı Gofret 29 g)
# 379   0.0642         (Ülker Krispi Baharatlı Çubuk Kraker 43 G)
# 365   0.0622                  (Ülker Dankek 8 Kek Çilekli 55 G)
# 354   0.0621                   (Ülker 8 Kek Orman Meyveli 55 G)

# %%
# Step 8: Generate Association Rules + IF Statements

# Filter to Top 50 Frequent Products
top_items = products.nlargest(50, 'Probability')['Product'].tolist()

# Create filtered transactions only containing those top items
filtered_transactions = [
    [item for item in basket if item in top_items] for basket in transactions
]

# One-Hot Encode the filtered transactions
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_array = te.fit_transform(filtered_transactions)
df_encoded = pd.DataFrame(te_array, columns=te.columns_)

# Run Apriori with lower support and max length to save memory
from mlxtend.frequent_patterns import apriori, association_rules

frequent_itemsets = apriori(df_encoded, min_support=0.001, use_colnames=True, max_len=3)
frequent_itemsets = frequent_itemsets.sort_values(by='support', ascending=False)

# Generate association rules with lowered confidence
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)
rules = rules.sort_values(by=['confidence', 'support'], ascending=[False, False])

# Display rules in IF-THEN format
if not rules.empty:
    for idx, row in rules.iterrows():
        antecedent = ', '.join(list(row['antecedents']))
        consequent = ', '.join(list(row['consequents']))
        print(f"IF a customer buys [{antecedent}] THEN they are likely to also buy [{consequent}]")
        print(f"   → Confidence: {row['confidence']:.2f}, Support: {row['support']:.3f}, Lift: {row['lift']:.2f}\n")
else:
    print("No association rules found with current thresholds.")

# Display top few rules as a DataFrame
rules.head()
# Out:
# IF a customer buys [Eti Gold Çikolatalı Gofret 29 g, İçim İçimino Laktozsuz Kakaolu Süt 180 Ml] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.34, Support: 0.001, Lift: 4.50
#
# IF a customer buys [İçim İçimino Laktozsuz Kakaolu Süt 180 Ml, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [Eti Gold Çikolatalı Gofret 29 g]
#    → Confidence: 0.29, Support: 0.001, Lift: 4.55
#
# IF a customer buys [Eti Gold Çikolatalı Gofret 29 g, Ülker Kremalı Sandviç Bisküvi 61 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.29, Support: 0.001, Lift: 3.77
#
# IF a customer buys [Ülker Kremalı Sandviç Bisküvi 61 G, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [Eti Gold Çikolatalı Gofret 29 g]
#    → Confidence: 0.27, Support: 0.001, Lift: 4.10
#
# IF a customer buys [Ülker Çikolatalı Gofret 36 G, Ülker Dankek 8 Kek Çilekli 55 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.24, Support: 0.001, Lift: 3.18
#
# IF a customer buys [Ülker Çokomel Marshmallow Sade 36 G, Indomie Sebzeli Noodle 75 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.24, Support: 0.001, Lift: 3.11
#
# IF a customer buys [Halley Çikolata Kaplamalı Bisküvi 30 G, Kekstra Konfeti Muffin Kek Kakaolu 38 G] THEN they are likely to also buy [Indomie Tavuk Noodle 70 G]
#    → Confidence: 0.22, Support: 0.001, Lift: 3.16
#
# IF a customer buys [Ülker Dankek 8 Kek Duble Çikolatalı 55 G, Ülker Yupo Çokojelo Böğürtlen 20 G] THEN they are likely to also buy [Ülker Dankek Pöti Havuçlu Tarçınlı 35 G]
#    → Confidence: 0.22, Support: 0.001, Lift: 3.05
#
# IF a customer buys [Eti Gold Çikolatalı Gofret 29 g, Indomie Gurme Acı Ve Baharatlı Hazır Noodle 80 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.22, Support: 0.001, Lift: 2.85
#
# IF a customer buys [Ülker Yupo Çokojelo Böğürtlen 20 G, Ülker Susamlı Çubuk Kraker 45 G] THEN they are likely to also buy [Indomie Sebzeli Noodle 75 G]
#    → Confidence: 0.22, Support: 0.001, Lift: 3.18
#
# IF a customer buys [Ülker Yupo Çokojelo Böğürtlen 20 G, Indomie Sebzeli Noodle 75 G] THEN they are likely to also buy [Ülker Susamlı Çubuk Kraker 45 G]
#    → Confidence: 0.22, Support: 0.001, Lift: 3.56
#
# IF a customer buys [Ülker Yupo Çokojelo Böğürtlen 20 G, Ülker Dankek Pöti Havuçlu Tarçınlı 35 G] THEN they are likely to also buy [Ülker Dankek 8 Kek Duble Çikolatalı 55 G]
#    → Confidence: 0.22, Support: 0.001, Lift: 3.51
#
# IF a customer buys [Indomie Gurme Acı Ve Baharatlı Hazır Noodle 80 G, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [Eti Gold Çikolatalı Gofret 29 g]
#    → Confidence: 0.21, Support: 0.001, Lift: 3.25
#
# IF a customer buys [Indomie Gurme Acı Ve Baharatlı Hazır Noodle 80 G, Ülker Dankek Pöti Havuçlu Tarçınlı 35 G] THEN they are likely to also buy [Ülker Kremalı Sandviç Bisküvi 61 G]
#    → Confidence: 0.21, Support: 0.001, Lift: 3.57
#
# IF a customer buys [Ülker Susamlı Çubuk Kraker 45 G, Indomie Sebzeli Noodle 75 G] THEN they are likely to also buy [Ülker Yupo Çokojelo Böğürtlen 20 G]
#    → Confidence: 0.20, Support: 0.001, Lift: 3.50
#
# IF a customer buys [Ülker 8 Kek Orman Meyveli 55 G, Indomie Tavuk Noodle 70 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.20, Support: 0.001, Lift: 2.61
#
# IF a customer buys [Ülker Dankek 8 Kek Duble Çikolatalı 55 G, Ülker Dankek Pöti Havuçlu Tarçınlı 35 G] THEN they are likely to also buy [Ülker Yupo Çokojelo Böğürtlen 20 G]
#    → Confidence: 0.20, Support: 0.001, Lift: 3.37
#
# IF a customer buys [Ülker Yupo Çokojelo Böğürtlen 20 G, Kekstra Konfeti Muffin Kek Kakaolu 38 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.20, Support: 0.001, Lift: 2.56
#
# IF a customer buys [Eti Gold Çikolatalı Gofret 29 g, Ülker Susamlı Çubuk Kraker 45 G] THEN they are likely to also buy [Halley Çikolata Kaplamalı Bisküvi 30 G]
#    → Confidence: 0.19, Support: 0.001, Lift: 3.19
#
# IF a customer buys [Eti Gold Çikolatalı Gofret 29 g, Halley Çikolata Kaplamalı Bisküvi 30 G] THEN they are likely to also buy [Ülker Susamlı Çubuk Kraker 45 G]
#    → Confidence: 0.19, Support: 0.001, Lift: 3.15
#
# IF a customer buys [Ülker Krispi Peynirli Çubuk Kraker 43 G, Indomie Sebzeli Noodle 75 G] THEN they are likely to also buy [Ülker Dankek Pöti Havuçlu Tarçınlı 35 G]
#    → Confidence: 0.19, Support: 0.001, Lift: 2.63
#
# IF a customer buys [Indomie Tavuk Noodle 70 G, Ülker Susamlı Çubuk Kraker 45 G] THEN they are likely to also buy [Halley Çikolata Kaplamalı Bisküvi 30 G]
#    → Confidence: 0.19, Support: 0.001, Lift: 3.13
#
# IF a customer buys [Ülker 9 Kat Tat Portakallı Gofret 39G, Ülker Dankek Pöti Havuçlu Tarçınlı 35 G] THEN they are likely to also buy [Ülker Susamlı Çubuk Kraker 45 G]
#    → Confidence: 0.19, Support: 0.001, Lift: 3.09
#
# IF a customer buys [Ülker Krispi Peynirli Çubuk Kraker 43 G, Ülker Dankek Pöti Havuçlu Tarçınlı 35 G] THEN they are likely to also buy [Indomie Sebzeli Noodle 75 G]
#    → Confidence: 0.19, Support: 0.001, Lift: 2.73
#
# IF a customer buys [Indomie Tavuk Noodle 70 G, Kekstra Konfeti Muffin Kek Kakaolu 38 G] THEN they are likely to also buy [Halley Çikolata Kaplamalı Bisküvi 30 G]
#    → Confidence: 0.19, Support: 0.001, Lift: 3.07
#
# IF a customer buys [Ülker Kremalı Sandviç Bisküvi 61 G, Indomie Gurme Acı Ve Baharatlı Hazır Noodle 80 G] THEN they are likely to also buy [Ülker Dankek Pöti Havuçlu Tarçınlı 35 G]
#    → Confidence: 0.19, Support: 0.001, Lift: 2.56
#
# IF a customer buys [Eti Gold Çikolatalı Gofret 29 g, Alpella Kakaolu Kaplamalı Kremalı Mini Rulo Pasta 28 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.19, Support: 0.001, Lift: 2.42
#
# IF a customer buys [Ülker Krispi Peynirli Çubuk Kraker 43 G, Indomie Tavuk Noodle 70 G] THEN they are likely to also buy [Indomie Sebzeli Noodle 75 G]
#    → Confidence: 0.18, Support: 0.001, Lift: 2.66
#
# IF a customer buys [Ülker Çokomel Marshmallow Sade 36 G, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [Indomie Sebzeli Noodle 75 G]
#    → Confidence: 0.18, Support: 0.001, Lift: 2.66
#
# IF a customer buys [Ülker 9 Kat Tat Portakallı Gofret 39G, Ülker Susamlı Çubuk Kraker 45 G] THEN they are likely to also buy [Ülker Dankek Pöti Havuçlu Tarçınlı 35 G]
#    → Confidence: 0.18, Support: 0.001, Lift: 2.52
#
# IF a customer buys [Ülker Çikolatalı Gofret 36 G, Indomie Sebzeli Noodle 75 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.18, Support: 0.001, Lift: 2.35
#
# IF a customer buys [Ülker Susamlı Çubuk Kraker 45 G, Halley Çikolata Kaplamalı Bisküvi 30 G] THEN they are likely to also buy [Indomie Tavuk Noodle 70 G]
#    → Confidence: 0.18, Support: 0.001, Lift: 2.54
#
# IF a customer buys [Ülker Susamlı Çubuk Kraker 45 G, Halley Çikolata Kaplamalı Bisküvi 30 G] THEN they are likely to also buy [Eti Gold Çikolatalı Gofret 29 g]
#    → Confidence: 0.18, Support: 0.001, Lift: 2.76
#
# IF a customer buys [Indomie Sebzeli Noodle 75 G, Ülker Dankek Pöti Havuçlu Tarçınlı 35 G] THEN they are likely to also buy [Ülker Krispi Peynirli Çubuk Kraker 43 G]
#    → Confidence: 0.18, Support: 0.001, Lift: 2.70
#
# IF a customer buys [Ülker Krispi Peynirli Çubuk Kraker 43 G, Indomie Sebzeli Noodle 75 G] THEN they are likely to also buy [Indomie Tavuk Noodle 70 G]
#    → Confidence: 0.17, Support: 0.001, Lift: 2.45
#
# IF a customer buys [Eti Gold Çikolatalı Gofret 29 g, Indomie Sebzeli Noodle 75 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.17, Support: 0.001, Lift: 2.25
#
# IF a customer buys [Eti Gold Çikolatalı Gofret 29 g, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [Ülker Kremalı Sandviç Bisküvi 61 G]
#    → Confidence: 0.17, Support: 0.001, Lift: 2.93
#
# IF a customer buys [Ülker Kremalı Sandviç Bisküvi 61 G, Ülker Dankek Pöti Havuçlu Tarçınlı 35 G] THEN they are likely to also buy [Indomie Gurme Acı Ve Baharatlı Hazır Noodle 80 G]
#    → Confidence: 0.17, Support: 0.001, Lift: 2.97
#
# IF a customer buys [Kekstra Konfeti Muffin Kek Kakaolu 38 G, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [Ülker Yupo Çokojelo Böğürtlen 20 G]
#    → Confidence: 0.17, Support: 0.001, Lift: 2.91
#
# IF a customer buys [Ülker Çikolatalı Gofret 36 G, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [Indomie Sebzeli Noodle 75 G]
#    → Confidence: 0.17, Support: 0.001, Lift: 2.48
#
# IF a customer buys [Ülker Yupo Çokojelo Böğürtlen 20 G, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [Kekstra Konfeti Muffin Kek Kakaolu 38 G]
#    → Confidence: 0.17, Support: 0.001, Lift: 2.92
#
# IF a customer buys [Indomie Tavuk Noodle 70 G, Halley Çikolata Kaplamalı Bisküvi 30 G] THEN they are likely to also buy [Kekstra Konfeti Muffin Kek Kakaolu 38 G]
#    → Confidence: 0.16, Support: 0.001, Lift: 2.87
#
# IF a customer buys [Indomie Tavuk Noodle 70 G, Halley Çikolata Kaplamalı Bisküvi 30 G] THEN they are likely to also buy [Ülker Susamlı Çubuk Kraker 45 G]
#    → Confidence: 0.16, Support: 0.001, Lift: 2.68
#
# IF a customer buys [Ülker Badem Kraker Sade 38 G, Ülker Dankek 8 Kek Çilekli 55 G] THEN they are likely to also buy [Ülker Çikolatalı Gofret 36 G]
#    → Confidence: 0.16, Support: 0.001, Lift: 2.85
#
# IF a customer buys [Ülker 8 Kek Orman Meyveli 55 G, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [Indomie Tavuk Noodle 70 G]
#    → Confidence: 0.16, Support: 0.001, Lift: 2.29
#
# IF a customer buys [Eti Gold Çikolatalı Gofret 29 g, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [Indomie Gurme Acı Ve Baharatlı Hazır Noodle 80 G]
#    → Confidence: 0.16, Support: 0.001, Lift: 2.77
#
# IF a customer buys [Indomie Sebzeli Noodle 75 G, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [Ülker Çikolatalı Gofret 36 G]
#    → Confidence: 0.15, Support: 0.001, Lift: 2.69
#
# IF a customer buys [Indomie Tavuk Noodle 70 G, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [Ülker 8 Kek Orman Meyveli 55 G]
#    → Confidence: 0.15, Support: 0.001, Lift: 2.48
#
# IF a customer buys [Ülker Çikolatalı Gofret 36 G, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [Ülker Dankek 8 Kek Çilekli 55 G]
#    → Confidence: 0.15, Support: 0.001, Lift: 2.47
#
# IF a customer buys [Alpella Kakaolu Kaplamalı Kremalı Mini Rulo Pasta 28 G, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [Eti Gold Çikolatalı Gofret 29 g]
#    → Confidence: 0.15, Support: 0.001, Lift: 2.31
#
# IF a customer buys [Indomie Sebzeli Noodle 75 G, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [Ülker Çokomel Marshmallow Sade 36 G]
#    → Confidence: 0.14, Support: 0.001, Lift: 3.17
#
# IF a customer buys [Indomie Sebzeli Noodle 75 G, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [Eti Gold Çikolatalı Gofret 29 g]
#    → Confidence: 0.14, Support: 0.001, Lift: 2.18
#
# IF a customer buys [Ülker Susamlı Çubuk Kraker 45 G, Ülker Dankek Pöti Havuçlu Tarçınlı 35 G] THEN they are likely to also buy [Ülker 9 Kat Tat Portakallı Gofret 39G]
#    → Confidence: 0.14, Support: 0.001, Lift: 2.45
#
# IF a customer buys [Takvim Gazetesi] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.13, Support: 0.005, Lift: 1.76
#
# IF a customer buys [Eti Gold Çikolatalı Gofret 29 g, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [İçim İçimino Laktozsuz Kakaolu Süt 180 Ml]
#    → Confidence: 0.13, Support: 0.001, Lift: 3.68
#
# IF a customer buys [Eti Gold Çikolatalı Gofret 29 g, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [Alpella Kakaolu Kaplamalı Kremalı Mini Rulo Pasta 28 G]
#    → Confidence: 0.13, Support: 0.001, Lift: 2.03
#
# IF a customer buys [Eti Gold Çikolatalı Gofret 29 g, Ülker Badem Kraker Sade 38 G] THEN they are likely to also buy [Indomie Sebzeli Noodle 75 G]
#    → Confidence: 0.13, Support: 0.001, Lift: 1.93
#
# IF a customer buys [Indomie Tavuk Noodle 70 G, Indomie Sebzeli Noodle 75 G] THEN they are likely to also buy [Ülker Krispi Peynirli Çubuk Kraker 43 G]
#    → Confidence: 0.13, Support: 0.001, Lift: 1.95
#
# IF a customer buys [Pınar Kido Kakaolu Süt 180 Ml] THEN they are likely to also buy [Ülker Krispi Baharatlı Çubuk Kraker 43 G]
#    → Confidence: 0.13, Support: 0.005, Lift: 1.97
#
# IF a customer buys [Ülker Çokomel Marshmallow Sade 36 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.12, Support: 0.005, Lift: 1.62
#
# IF a customer buys [Knorr Çabuk Çorba Ramen 17 G] THEN they are likely to also buy [Halley Çikolata Kaplamalı Bisküvi 30 G]
#    → Confidence: 0.12, Support: 0.004, Lift: 1.97
#
# IF a customer buys [Eti Gold Çikolatalı Gofret 29 g] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.12, Support: 0.008, Lift: 1.53
#
# IF a customer buys [Uno Çikolata Kremalı Kruvasan 30 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.12, Support: 0.005, Lift: 1.53
#
# IF a customer buys [Ülker Susamlı Çubuk Kraker 45 G] THEN they are likely to also buy [Ülker Dankek Pöti Havuçlu Tarçınlı 35 G]
#    → Confidence: 0.12, Support: 0.007, Lift: 1.61
#
# IF a customer buys [Indomie Sebzeli Noodle 75 G] THEN they are likely to also buy [Indomie Tavuk Noodle 70 G]
#    → Confidence: 0.11, Support: 0.008, Lift: 1.62
#
# IF a customer buys [Ülker Çikolatalı Gofret 36 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.11, Support: 0.006, Lift: 1.48
#
# IF a customer buys [Ülker Çokomel Marshmallow Çilekli 36 G] THEN they are likely to also buy [Indomie Tavuk Noodle 70 G]
#    → Confidence: 0.11, Support: 0.005, Lift: 1.61
#
# IF a customer buys [Pınar Kido Çilekli Süt 180 Ml] THEN they are likely to also buy [Ülker Dankek Pöti Havuçlu Tarçınlı 35 G]
#    → Confidence: 0.11, Support: 0.004, Lift: 1.56
#
# IF a customer buys [İçim İçimino Laktozsuz Kakaolu Süt 180 Ml] THEN they are likely to also buy [Indomie Tavuk Noodle 70 G]
#    → Confidence: 0.11, Support: 0.004, Lift: 1.59
#
# IF a customer buys [Eti Susamlı Çubuk Kraker 56 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.11, Support: 0.005, Lift: 1.46
#
# IF a customer buys [Ülker Kremalı Sandviç Bisküvi 61 G] THEN they are likely to also buy [Alpella Kakaolu Kaplamalı Kremalı Mini Rulo Pasta 28 G]
#    → Confidence: 0.11, Support: 0.006, Lift: 1.72
#
# IF a customer buys [Indomie Tavuk Noodle 70 G] THEN they are likely to also buy [Indomie Sebzeli Noodle 75 G]
#    → Confidence: 0.11, Support: 0.008, Lift: 1.62
#
# IF a customer buys [Uno Çikolata Kremalı Kruvasan 30 G] THEN they are likely to also buy [Ülker Krispi Baharatlı Çubuk Kraker 43 G]
#    → Confidence: 0.11, Support: 0.005, Lift: 1.72
#
# IF a customer buys [Ülker Albeni Viva Beyaz Çikolata Kaplamalı Bar 36G] THEN they are likely to also buy [Eti Gold Çikolatalı Gofret 29 g]
#    → Confidence: 0.11, Support: 0.004, Lift: 1.70
#
# IF a customer buys [Ülker Albeni Viva Beyaz Çikolata Kaplamalı Bar 36G] THEN they are likely to also buy [Ülker Susamlı Çubuk Kraker 45 G]
#    → Confidence: 0.11, Support: 0.004, Lift: 1.80
#
# IF a customer buys [Dimes Ananas Aromalı İçecek 200 Ml] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.11, Support: 0.005, Lift: 1.44
#
# IF a customer buys [Eti Crax Çubuk Kraker 85 g] THEN they are likely to also buy [Indomie Sebzeli Noodle 75 G]
#    → Confidence: 0.11, Support: 0.006, Lift: 1.58
#
# IF a customer buys [Uno Çikolata Kremalı Kruvasan 30 G] THEN they are likely to also buy [Ülker Dankek 8 Kek Çilekli 55 G]
#    → Confidence: 0.11, Support: 0.005, Lift: 1.74
#
# IF a customer buys [Ülker Albeni Viva Beyaz Çikolata Kaplamalı Bar 36G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.11, Support: 0.004, Lift: 1.40
#
# IF a customer buys [Sek Süt 200 Ml] THEN they are likely to also buy [Indomie Tavuk Noodle 70 G]
#    → Confidence: 0.11, Support: 0.004, Lift: 1.52
#
# IF a customer buys [Knorr Çabuk Çorba Ramen 17 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.11, Support: 0.004, Lift: 1.39
#
# IF a customer buys [Ülker Krispi Tırtıklı Baharatlı 48 G] THEN they are likely to also buy [Ülker 8 Kek Orman Meyveli 55 G]
#    → Confidence: 0.11, Support: 0.005, Lift: 1.72
#
# IF a customer buys [Tamek Kayısı Nektarı 200 Ml] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.11, Support: 0.005, Lift: 1.39
#
# IF a customer buys [Ülker Çikolatalı Gofret 36 G] THEN they are likely to also buy [Indomie Sebzeli Noodle 75 G]
#    → Confidence: 0.11, Support: 0.006, Lift: 1.55
#
# IF a customer buys [Eti Pizza Kraker 76 G] THEN they are likely to also buy [Ülker Dankek Pöti Havuçlu Tarçınlı 35 G]
#    → Confidence: 0.11, Support: 0.005, Lift: 1.46
#
# IF a customer buys [Indomie Gurme Acı Ve Baharatlı Hazır Noodle 80 G] THEN they are likely to also buy [Eti Crax Çubuk Kraker 85 g]
#    → Confidence: 0.11, Support: 0.006, Lift: 1.75
#
# IF a customer buys [Ülker Susamlı Çubuk Kraker 70 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.11, Support: 0.005, Lift: 1.37
#
# IF a customer buys [Alpella Kakaolu Kaplamalı Kremalı Mini Rulo Pasta 28 G] THEN they are likely to also buy [Indomie Tavuk Noodle 70 G]
#    → Confidence: 0.10, Support: 0.007, Lift: 1.49
#
# IF a customer buys [Eti Crax Çubuk Kraker 85 g] THEN they are likely to also buy [Ülker Krispi Baharatlı Çubuk Kraker 43 G]
#    → Confidence: 0.10, Support: 0.006, Lift: 1.63
#
# IF a customer buys [Sek Süt 200 Ml] THEN they are likely to also buy [Ülker Dankek Pöti Havuçlu Tarçınlı 35 G]
#    → Confidence: 0.10, Support: 0.004, Lift: 1.45
#
# IF a customer buys [Ülker Krispi Tırtıklı Baharatlı 48 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.10, Support: 0.005, Lift: 1.36
#
# IF a customer buys [Indomie Sebzeli Noodle 75 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.10, Support: 0.007, Lift: 1.36
#
# IF a customer buys [Knorr Çabuk Çorba Ramen 17 G] THEN they are likely to also buy [Ülker Krispi Peynirli Çubuk Kraker 43 G]
#    → Confidence: 0.10, Support: 0.004, Lift: 1.58
#
# IF a customer buys [Knorr Çabuk Çorba Ramen 17 G] THEN they are likely to also buy [Eti Gold Çikolatalı Gofret 29 g]
#    → Confidence: 0.10, Support: 0.004, Lift: 1.61
#
# IF a customer buys [Uno Çikolata Kremalı Kruvasan 30 G] THEN they are likely to also buy [Ülker Dankek Pöti Havuçlu Tarçınlı 35 G]
#    → Confidence: 0.10, Support: 0.004, Lift: 1.43
#
# IF a customer buys [Alpella Kakaolu Kaplamalı Kremalı Mini Rulo Pasta 28 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.10, Support: 0.007, Lift: 1.35
#
# IF a customer buys [Ülker Çokomel Marshmallow Çilekli 36 G] THEN they are likely to also buy [Ülker Krispi Baharatlı Çubuk Kraker 43 G]
#    → Confidence: 0.10, Support: 0.004, Lift: 1.61
#
# IF a customer buys [İçim İçimino Laktozsuz Kakaolu Süt 180 Ml] THEN they are likely to also buy [Indomie Sebzeli Noodle 75 G]
#    → Confidence: 0.10, Support: 0.004, Lift: 1.51
#
# IF a customer buys [İçim İçimino Laktozsuz Kakaolu Süt 180 Ml] THEN they are likely to also buy [Ülker Krispi Peynirli Çubuk Kraker 43 G]
#    → Confidence: 0.10, Support: 0.004, Lift: 1.57
#
# IF a customer buys [Kekstra Konfeti Muffin Kek Kakaolu 38 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.10, Support: 0.006, Lift: 1.35
#
# IF a customer buys [Ülker Yupo Çokojelo Böğürtlen 20 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.10, Support: 0.006, Lift: 1.34
#
# IF a customer buys [Eti Karamelli Patlaklı Sütlü Çikolata 15 G] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.10, Support: 0.004, Lift: 1.34
#
# IF a customer buys [Ülker Çikolatalı Gofret Maxi 47 G] THEN they are likely to also buy [Ülker Dankek Pöti Havuçlu Tarçınlı 35 G]
#    → Confidence: 0.10, Support: 0.004, Lift: 1.42
#
# IF a customer buys [Kekstra Konfeti Muffin Kek Kakaolu 38 G] THEN they are likely to also buy [Indomie Sebzeli Noodle 75 G]
#    → Confidence: 0.10, Support: 0.006, Lift: 1.49
#
# IF a customer buys [Eti Crax Çubuk Kraker 85 g] THEN they are likely to also buy [Ülker Badem Kraker Sade 38 G]
#    → Confidence: 0.10, Support: 0.006, Lift: 1.33
#
# IF a customer buys [Ülker Çokomel Marshmallow Sade 36 G] THEN they are likely to also buy [Ülker Dankek Pöti Havuçlu Tarçınlı 35 G]
#    → Confidence: 0.10, Support: 0.004, Lift: 1.40
#
# IF a customer buys [Ülker Kremalı Sandviç Bisküvi 61 G] THEN they are likely to also buy [Ülker Dankek Pöti Havuçlu Tarçınlı 35 G]
#    → Confidence: 0.10, Support: 0.006, Lift: 1.40
#
# IF a customer buys [Halley Çikolata Kaplamalı Bisküvi 30 G] THEN they are likely to also buy [Indomie Tavuk Noodle 70 G]
#    → Confidence: 0.10, Support: 0.006, Lift: 1.44
#
# IF a customer buys [Uno Çikolata Kremalı Kruvasan 30 G] THEN they are likely to also buy [Eti Gold Çikolatalı Gofret 29 g]
#    → Confidence: 0.10, Support: 0.004, Lift: 1.56
#
# IF a customer buys [Knorr Çabuk Çorba Ramen 17 G] THEN they are likely to also buy [Ülker Dankek 8 Kek Çilekli 55 G]
#    → Confidence: 0.10, Support: 0.003, Lift: 1.62
#
# IF a customer buys [Ülker Krispi Tırtıklı Acılı Kraker 48 G] THEN they are likely to also buy [Ülker 8 Kek Orman Meyveli 55 G]
#    → Confidence: 0.10, Support: 0.004, Lift: 1.62
#
# IF a customer buys [Pınar Kido Çilekli Süt 180 Ml] THEN they are likely to also buy [Eti Gold Çikolatalı Gofret 29 g]
#    → Confidence: 0.10, Support: 0.003, Lift: 1.55
#
# IF a customer buys [Ülker Susamlı Çubuk Kraker 70 G] THEN they are likely to also buy [Eti Crax Çubuk Kraker 85 g]
#    → Confidence: 0.10, Support: 0.004, Lift: 1.67
#
# IF a customer buys [Tamek Limo Elma Aromalı Limonata 200 Ml] THEN they are likely to also buy [Alpella Kakaolu Kaplamalı Kremalı Mini Rulo Pasta 28 G]
#    → Confidence: 0.10, Support: 0.004, Lift: 1.55
#
# IF a customer buys [Alpella Kakaolu Kaplamalı Kremalı Mini Rulo Pasta 28 G] THEN they are likely to also buy [Ülker Kremalı Sandviç Bisküvi 61 G]
#    → Confidence: 0.10, Support: 0.006, Lift: 1.72
#                                            antecedents  \
# 74   (Eti Gold Çikolatalı Gofret 29 g, İçim İçimino...
# 75   (İçim İçimino Laktozsuz Kakaolu Süt 180 Ml, Ül...
# 58   (Eti Gold Çikolatalı Gofret 29 g, Ülker Kremal...
# 60   (Ülker Kremalı Sandviç Bisküvi 61 G, Ülker Bad...
# 110  (Ülker Çikolatalı Gofret 36 G, Ülker Dankek 8 ...
#
#                            consequents  antecedent support  \
# 74      (Ülker Badem Kraker Sade 38 G)              0.0029
# 75   (Eti Gold Çikolatalı Gofret 29 g)              0.0034
# 58      (Ülker Badem Kraker Sade 38 G)              0.0045
# 60   (Eti Gold Çikolatalı Gofret 29 g)              0.0049
# 110     (Ülker Badem Kraker Sade 38 G)              0.0041
#
#      consequent support  support  confidence      lift  representativity  \
# 74               0.0766   0.0010    0.344828  4.501666               1.0
# 75               0.0647   0.0010    0.294118  4.545868               1.0
# 58               0.0766   0.0013    0.288889  3.771395               1.0
# 60               0.0647   0.0013    0.265306  4.100558               1.0
# 110              0.0766   0.0010    0.243902  3.184105               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 74   0.000778    1.409400       0.780122  0.012739   0.290478    0.178941
# 75   0.000780    1.325008       0.782681  0.014903   0.245288    0.154787
# 58   0.000955    1.298531       0.738168  0.016291   0.229899    0.152930
# 60   0.000983    1.273047       0.759854  0.019034   0.214483    0.142699
# 110  0.000686    1.221271       0.688764  0.012547   0.181181    0.128479

# %%
#📘 Top 10 Association Rules with Business Insights
#1.
#Rule:
#If a customer buys Eti Gold Çikolatalı Gofret 29 g and İçim İçimino Laktozsuz Kakaolu Süt 180 Ml,
#Then they are likely to also buy Ülker Badem Kraker Sade 38 G
#Confidence: 34% — Lift: 4.50

#📈 Insight: These three snack products are often bought together, suggesting they're popular for on-the-go snacking or school/work lunches.

#💡 Action: Place them in a combo pack or create a "Snack Trio" shelf in convenience sections.

#2.
#Rule:
#If a customer buys İçim İçimino Kakaolu Süt and Ülker Badem Kraker,
#Then they are likely to also buy Eti Gold Gofret
#Confidence: 29% — Lift: 4.55

#📈 Insight: Customers grabbing a drink and a salty snack are also inclined toward a sweet bar.

#💡 Action: Offer a buy-2-get-1-free or bundled discount on these 3.

#3.
#Rule:
#If a customer buys Ülker Çokomel Marshmallow and Indomie Noodle,
#Then they are likely to also buy Ülker Badem Kraker
#Confidence: 24% — Lift: 3.11

#📈 Insight: Suggests evening snack + quick dinner pattern.

#💡 Action: Shelf together in late-evening aisles or near microwaves. Offer a "Netflix Night" snack combo.

#4.
#Rule:
#If a customer buys Halley Bisküvi and Kekstra Muffin,
#Then they are likely to also buy Indomie Chicken Noodle
#Confidence: 22% — Lift: 3.16

#📈 Insight: Sweet snacks are often paired with quick meals.

#💡 Action: Create "meal & dessert" kits targeting students or night-shift workers.

#5.
#ule:
#If a customer buys Ülker Dankek 8 Kek and Yupo Çokojelo,
#Then they are likely to also buy Dankek Havuçlu Tarçınlı
#Confidence: 22% — Lift: 3.05

#📈 Insight: Customers buying sweets often pick up more than one variety.

#💡 Action: Use this for flavor-variant cross-promotion or “Mix 3 for a Deal” campaigns.

#6.
#Rule:
#If a customer buys Eti Gold Gofret and Indomie Gurme Noodle,
#Then they are likely to also buy Ülker Badem Kraker
#Confidence: 22% — Lift: 2.85

#📈 Insight: Suggests cross-category purchases from different sections (sweet bar, noodle, savory snack).

#💡 Action: Bundle across categories — cross-department promotions.

#7.
#Rule:
#If a customer buys Ülker Dankek Duble Kek and Dankek Havuçlu Tarçınlı,
#Then they are likely to also buy Yupo Çokojelo
#Confidence: 20% — Lift: 3.37

#📈 Insight: Again reinforces the multi-dessert or variety-seeking behavior.

#💡 Action: Optimize assortment layout in bakery or snack aisle for easier flavor comparison.

#8.
#Rule:
#If a customer buys Ülker Susamlı Kraker and Indomie Noodle,
#Then they are likely to also buy Halley Bisküvi
#Confidence: 19% — Lift: 3.13

#📈 Insight: A clear meal + treat buying behavior.

#💡 Action: Position sweet biscuits near noodles — cross-sell in dinner sections.

#9.
#Rule:
#If a customer buys Kekstra Muffin and Yupo Çokojelo,
#Then they are likely to also buy Badem Kraker
#Confidence: 20% — Lift: 2.56

#📈 Insight: Sweet items are linked to salty cravings.

#💡 Action: Apply dynamic pricing when sweet and salty items are bought together — to increase average basket value.

#10.
#Rule:
#If a customer buys Eti Gold Gofret and Ülker Badem Kraker,
#Then they are likely to also buy İçim Kakaolu Süt
#Confidence: 13% — Lift: 3.68

#📈 Insight: A popular on-the-go snack + drink combo.

#💡 Action: Add these to a meal-deal shelf at checkout or near refrigerated drinks.

#📌 Conclusion
#These patterns reveal real opportunities in:

#   Product placement

#   Combo offers

#   Cross-category bundles

#   Personalized promotions (via loyalty apps)

# %%
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd

# One-hot encode the filtered transactions
te = TransactionEncoder()
te_array = te.fit_transform(filtered_transactions)

# Create DataFrame: columns = products, rows = customers
df_wide_format = pd.DataFrame(te_array, columns=te.columns_)

# Add a TransactionID column (row = customer)
df_wide_format.insert(0, 'TransactionID', range(1, len(df_wide_format) + 1))

# Export to CSV (rows = customers, columns = products)
df_wide_format.to_csv("synthetic_transactions_wide_format.csv", index=False)
